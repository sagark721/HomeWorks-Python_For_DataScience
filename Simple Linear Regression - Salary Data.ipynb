# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
sns.scatterplot(x=df['YearsExperience'],y=df['Salary'])
# Out:
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.regplot(x=df['YearsExperience'],y=df['Salary'])
# Out:
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %%
X=df['YearsExperience']
y=df['Salary']

# %%
np.polyfit(X,y,deg=1)
# Out:
# array([ 9449.96232146, 25792.20019867])

# %%
#y=mx+b
#y=b1*x+b0

# %%
Years_of_Experience=7
predicted_salary=(9449.96232146*Years_of_Experience) + 25792.20019867

# %%
predicted_salary
# Out:
# 91941.93644889

# %%
Years_of_Experience=input("Enter Years of Experience to predict the salary.")
predicted_salary=(9449.96232146*int(Years_of_Experience)) + 25792.20019867
print("Predicted salary for {} years of experiance is {}".format(Years_of_Experience,predicted_salary))
# Out:
# Enter Years of Experience to predict the salary.7
# Predicted salary for 7 years of experiance is 91941.93644889
